# %%
# !pip install pandasql
# Out:
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pandasql) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pandasql) (2.2.2)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.12/dist-packages (from pandasql) (2.0.43)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->pandasql) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy->pandasql) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy->pandasql) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->pandasql) (1.17.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26773 sha256=f231ed3f5f2471e5f6a6b4d0605ebbddce070798ecfc13906f5a4e2f8409f95c
#   Stored in directory: /root/.cache/pip/wheels/15/a1/e7/6f92f295b5272ae5c02365e6b8fa19cb93f16a537090a1cf27
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %%
from pandasql import sqldf

# Define a reusable function for running SQL queries
run_query = lambda query: sqldf(query, globals())

# %%
import pandas as pd
import seaborn as sns
from pandasql import sqldf

# %%
# Load the "tips" dataset into a Pandas DataFrame
tips_df = sns.load_dataset("tips")

# %%
query_1 = """
SELECT *
FROM tips_df
LIMIT 10;
"""

# Using the run_query function
result_1 = run_query(query_1)
result_1
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
# filtering based on a condition
query_2 = """
SELECT *
FROM tips_df
WHERE total_bill > 30 AND tip > 5;
"""

result_2 = run_query(query_2)
result_2
# Out:
#    total_bill    tip     sex smoker   day    time  size
# 0       39.42   7.58    Male     No   Sat  Dinner     4
# 1       30.40   5.60    Male     No   Sun  Dinner     4
# 2       32.40   6.00    Male     No   Sun  Dinner     4
# 3       34.81   5.20  Female     No   Sun  Dinner     4
# 4       48.27   6.73    Male     No   Sat  Dinner     4
# 5       34.83   5.17  Female     No  Thur   Lunch     4
# 6       34.30   6.70    Male     No  Thur   Lunch     6
# 7       50.81  10.00    Male    Yes   Sat  Dinner     3
# 8       48.33   9.00    Male     No   Sat  Dinner     4

# %%
# grouping and aggregation
query_3 = """
SELECT day, AVG(total_bill) as avg_bill
FROM tips_df
GROUP BY day;
"""

result_3 = run_query(query_3)
result_3
# Out:
#     day   avg_bill
# 0   Fri  17.151579
# 1   Sat  20.441379
# 2   Sun  21.410000
# 3  Thur  17.682742

# %%
query_4 = """
SELECT day, COUNT(*) as num_transactions, AVG(total_bill) as avg_bill, MAX(tip) as max_tip
FROM tips_df
GROUP BY day;
"""

result_4 = run_query(query_4)
result_4
# Out:
#     day  num_transactions   avg_bill  max_tip
# 0   Fri                19  17.151579     4.73
# 1   Sat                87  20.441379    10.00
# 2   Sun                76  21.410000     6.50
# 3  Thur                62  17.682742     6.70

# %%
# subqueries
query_5 = """
SELECT *
FROM tips_df
WHERE total_bill > (SELECT AVG(total_bill) FROM tips_df);
"""

result_5 = run_query(query_5)
result_5
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        21.01  3.50    Male     No  Sun  Dinner     3
# 1        23.68  3.31    Male     No  Sun  Dinner     2
# 2        24.59  3.61  Female     No  Sun  Dinner     4
# 3        25.29  4.71    Male     No  Sun  Dinner     4
# 4        26.88  3.12    Male     No  Sun  Dinner     4
# ..         ...   ...     ...    ...  ...     ...   ...
# 94       32.83  1.17    Male    Yes  Sat  Dinner     2
# 95       35.83  4.67  Female     No  Sat  Dinner     3
# 96       29.03  5.92    Male     No  Sat  Dinner     3
# 97       27.18  2.00  Female    Yes  Sat  Dinner     2
# 98       22.67  2.00    Male    Yes  Sat  Dinner     2
#
# [99 rows x 7 columns]

# %%
# Create another DataFrame to join with tips_df
other_data = pd.DataFrame({
    'day': ['Thur','Fri', 'Sat', 'Sun'],
    'special_event': ['Throwback Thursday', 'Feel Good Friday', 'Social Saturday','Fun Sunday', ]
})

# %%
query_6 = """
SELECT t.*, o.special_event
FROM tips_df t
LEFT JOIN other_data o ON t.day = o.day;
"""

result_6 = run_query(query_6)
result_6
# Out:
#      total_bill   tip     sex smoker   day    time  size       special_event
# 0         16.99  1.01  Female     No   Sun  Dinner     2          Fun Sunday
# 1         10.34  1.66    Male     No   Sun  Dinner     3          Fun Sunday
# 2         21.01  3.50    Male     No   Sun  Dinner     3          Fun Sunday
# 3         23.68  3.31    Male     No   Sun  Dinner     2          Fun Sunday
# 4         24.59  3.61  Female     No   Sun  Dinner     4          Fun Sunday
# ..          ...   ...     ...    ...   ...     ...   ...                 ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     Social Saturday
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     Social Saturday
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     Social Saturday
# 242       17.82  1.75    Male     No   Sat  Dinner     2     Social Saturday
# 243       18.78  3.00  Female     No  Thur  Dinner     2  Throwback Thursday
#
# [244 rows x 8 columns]
