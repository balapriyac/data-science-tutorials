# %%
import pandas as pd
import numpy as np

np.random.seed(42)
n = 100_000

categories = ['Electronics', 'Clothing', 'Home & Kitchen', 'Sports', 'Books']
regions = ['North', 'South', 'East', 'West']

df = pd.DataFrame({
    'order_id': range(1, n + 1),
    'customer_age': np.random.randint(18, 70, n),
    'product_category': np.random.choice(categories, n),
    'region': np.random.choice(regions, n),
    'price': np.round(np.random.uniform(5.0, 500.0, n), 2),
    'quantity': np.random.randint(1, 10, n),
    'days_to_ship': np.random.randint(1, 14, n),
})
display(df.head())
# Out:
#    order_id  customer_age product_category region   price  quantity  \
# 0         1            56           Sports   West  128.57         2
# 1         2            69         Clothing  North  183.80         4
# 2         3            46      Electronics   West  351.60         5
# 3         4            32            Books   West  402.98         6
# 4         5            60   Home & Kitchen   West   56.41         3
#
#    days_to_ship
# 0             6
# 1             5
# 2            12
# 3             5
# 4            10

# %%
df['revenue'] = df['price'] * df['quantity']
display(df[['price', 'quantity', 'revenue']].head())
# Out:
#     price  quantity  revenue
# 0  128.57         2   257.14
# 1  183.80         4   735.20
# 2  351.60         5  1758.00
# 3  402.98         6  2417.88
# 4   56.41         3   169.23

# %%
def shipping_label(days):
    if days <= 2:
        return 'Express'
    elif days <= 5:
        return 'Standard'
    else:
        return 'Economy'

df['shipping_tier'] = df['days_to_ship'].apply(shipping_label)
display(df[['days_to_ship', 'shipping_tier']].head())
# Out:
#    days_to_ship shipping_tier
# 0             6       Economy
# 1             5      Standard
# 2            12       Economy
# 3             5      Standard
# 4            10       Economy

# %%
df['senior_discount'] = np.where(df['customer_age'] >= 60, True, False)
display(df[['customer_age', 'senior_discount']].head())
# Out:
#    customer_age  senior_discount
# 0            56            False
# 1            69             True
# 2            46            False
# 3            32            False
# 4            60             True

# %%
conditions = [
    df['region'] == 'North',
    df['region'] == 'South',
    df['region'] == 'East',
    df['region'] == 'West',
]
tax_rates = [0.08, 0.06, 0.07, 0.09]

df['tax_rate'] = np.select(conditions, tax_rates, default=0.07)
df['tax_amount'] = df['price'] * df['tax_rate']
display(df[['region', 'price', 'tax_rate', 'tax_amount']].head())
# Out:
#   region   price  tax_rate  tax_amount
# 0   West  128.57      0.09     11.5713
# 1  North  183.80      0.08     14.7040
# 2   West  351.60      0.09     31.6440
# 3   West  402.98      0.09     36.2682
# 4   West   56.41      0.09      5.0769

# %%
category_codes = {
    'Electronics': 'ELEC',
    'Clothing': 'CLTH',
    'Home & Kitchen': 'HOME',
    'Sports': 'SPRT',
    'Books': 'BOOK',
}

df['dept_code'] = df['product_category'].map(category_codes)
display(df[['product_category', 'dept_code']].head())
# Out:
#   product_category dept_code
# 0           Sports      SPRT
# 1         Clothing      CLTH
# 2      Electronics      ELEC
# 3            Books      BOOK
# 4   Home & Kitchen      HOME

# %%
df['category_slug'] = df['product_category'].str.split().str[0].str.lower()
display(df[['product_category', 'category_slug']].head())
# Out:
#   product_category category_slug
# 0           Sports        sports
# 1         Clothing      clothing
# 2      Electronics   electronics
# 3            Books         books
# 4   Home & Kitchen          home

# %%
summary = (
    df.groupby('product_category')
    .agg(
        total_revenue=('revenue', 'sum'),
        avg_ship_days=('days_to_ship', 'mean'),
        order_count=('order_id', 'count')
    )
    .round(2)
    .reset_index()
)
summary
# Out:
#   product_category  total_revenue  avg_ship_days  order_count
# 0            Books    25302053.44           7.01        20071
# 1         Clothing    25393703.17           7.04        20083
# 2      Electronics    25159570.16           7.01        20029
# 3   Home & Kitchen    24984546.38           6.96        19902
# 4           Sports    25136596.16           6.98        19915
